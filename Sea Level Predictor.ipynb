# %%
# Import required libraries
import pandas as pd              # For data handling
import matplotlib.pyplot as plt  # For plotting graphs
from scipy.stats import linregress  # For linear regression

# %%
def draw_plot():
    # Load data
    df = pd.read_csv(r"C:\Users\tania\OneDrive\Documents\Data Projects\Python\Sea Level Predictor\epa-sea-level.csv")

    # Scatter plot
    plt.scatter(df["Year"], df["CSIRO Adjusted Sea Level"])

    # Line of best fit (all data)
    result = linregress(df["Year"], df["CSIRO Adjusted Sea Level"])
    years = pd.Series(range(df["Year"].min(), 2051))
    plt.plot(years, result.slope * years + result.intercept, color='red')

    # Line of best fit (from 2000)
    df_2000 = df[df["Year"] >= 2000]
    result_2000 = linregress(df_2000["Year"], df_2000["CSIRO Adjusted Sea Level"])
    years_2000 = pd.Series(range(2000, 2051))
    plt.plot(years_2000, result_2000.slope * years_2000 + result_2000.intercept, color='green')

    # Labels
    plt.xlabel("Year")
    plt.ylabel("Sea Level (inches)")
    plt.title("Rise in Sea Level")

    # Save and return
    plt.savefig("sea_level_plot.png")
    return plt.gca()

# %%
#show the plot
draw_plot()
plt.show()
